# %%
import pandas_datareader as pdr

# %%
alibaba = pdr.get_data_yahoo('AAPL')

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2009-12-31  30.478571  30.080000  30.447144  30.104286   88102700.0  26.372231
# 2010-01-04  30.642857  30.340000  30.490000  30.572857  123432400.0  26.782711
# 2010-01-05  30.798571  30.464285  30.657143  30.625713  150476200.0  26.829010
# 2010-01-06  30.747143  30.107143  30.625713  30.138571  138040000.0  26.402260
# 2010-01-07  30.285715  29.864286  30.250000  30.082857  119282800.0  26.353460

# %%
alibaba.shape
# Out:
# (2405, 6)

# %%
alibaba.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  2405.000000  2405.000000  2405.000000  2405.000000  2.405000e+03
# mean    105.312173   103.424262   104.384741   104.393315  7.712391e+07
# std      50.201379    49.377983    49.761677    49.802383  5.919374e+07
# min      28.000000    27.178572    27.481428    27.435715  1.136200e+07
# 25%      64.112854    62.885715    63.435715    63.275715  3.252700e+07
# 50%      97.699997    95.828575    96.820000    96.790001  5.870900e+07
# 75%     139.360001   137.600006   138.740005   138.960007  1.047326e+08
# max     233.470001   229.779999   230.779999   232.070007  4.702495e+08
#
#          Adj Close
# count  2405.000000
# mean     98.508836
# std      51.122563
# min      24.034487
# 25%      56.419884
# 50%      90.602806
# 75%     134.227295
# max     229.392090

# %%
alibaba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2405 entries, 2009-12-31 to 2019-07-23
# Data columns (total 6 columns):
# High         2405 non-null float64
# Low          2405 non-null float64
# Open         2405 non-null float64
# Close        2405 non-null float64
# Volume       2405 non-null float64
# Adj Close    2405 non-null float64
# dtypes: float64(6)
# memory usage: 131.5 KB

# %%
import numpy as np
import pandas as pd
from pandas import Series , DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from datetime import datetime

# %%
start = datetime(2015,1,1)
#alibaba = pdr.get_data_yahoo('AAPL')
amazon = pdr.get_data_yahoo('AMZN',start=start)

# %%
amazon

# %%
alibaba.to_csv('BABA.csv')
amazon.to_csv('AMZN.csv')

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2009-12-31  30.478571  30.080000  30.447144  30.104286   88102700.0  26.372231
# 2010-01-04  30.642857  30.340000  30.490000  30.572857  123432400.0  26.782711
# 2010-01-05  30.798571  30.464285  30.657143  30.625713  150476200.0  26.829010
# 2010-01-06  30.747143  30.107143  30.625713  30.138571  138040000.0  26.402260
# 2010-01-07  30.285715  29.864286  30.250000  30.082857  119282800.0  26.353460

# %%
alibaba['Adj Close'].plot(legend=True)

# %%
alibaba['Volume'].plot(legend=True)

# %%
# alibaba['Adj Close'].plot()
amazon['Adj Close'].plot()

# plt.plot(alibaba['Adj Close'])
# plt.plot(amazon['Adj Close'])

# %%
alibaba['high-low'] = alibaba['High']-alibaba['Low']

# %%
alibaba['high-low'].plot()

# %%
#daliy return
alibaba['daily'] = alibaba['Adj Close'].pct_change()
alibaba['daily'] .plot(figsize = (15,4),linestyle='--',marker='o')

# %%
alibaba['daily'] .plot(kind='hist')

# %%
sns.distplot(alibaba['daily'].dropna(),bins=100,color='purple')
# Out:
# F:\anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
