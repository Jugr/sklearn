# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series,DataFrame
import pandas as pd

# %%
s = Series(np.random.randn(1000))

# %%
plt.hist(s,rwidth=0.9,bins=20,color='r')
# Out:
# (array([  2.,   0.,   4.,  13.,  29.,  30.,  83.,  96., 125., 162., 143.,
#         109.,  81.,  61.,  37.,  13.,   8.,   3.,   0.,   1.]),
#  array([-3.63384707, -3.26347986, -2.89311266, -2.52274546, -2.15237825,
#         -1.78201105, -1.41164384, -1.04127664, -0.67090944, -0.30054223,
#          0.06982497,  0.44019217,  0.81055938,  1.18092658,  1.55129379,
#          1.92166099,  2.29202819,  2.6623954 ,  3.0327626 ,  3.4031298 ,
#          3.77349701]),
#  <a list of 20 Patch objects>)

# %%
#密度图
s.plot(kind='kde')
