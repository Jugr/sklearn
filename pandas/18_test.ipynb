# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
# !dir
# Out:
#  驱动器 D 中的卷是 新加卷
#  卷的序列号是 B89B-9934
#
#  D:\JupyterNotebookWorkplace\pandas 的目录
#
# 2019/07/18  19:07    <DIR>          .
# 2019/07/18  19:07    <DIR>          ..
# 2019/07/18  19:07    <DIR>          .ipynb_checkpoints
# 2019/07/17  13:19             8,096 01_series.ipynb
# 2019/07/15  21:45            28,903 02_DataFrame.ipynb
# 2019/07/16  13:13            11,474 03_Series&DataFrame.ipynb
# 2019/07/16  13:31            20,561 04_IO.ipynb
# 2019/07/16  14:40            57,987 05_Selecting&Indexing.ipynb
# 2019/07/17  13:30            27,722 06_Reindex Series and DataFrame.ipynb
# 2019/07/17  13:34            16,645 07_Nan.ipynb
# 2019/07/16  15:26            11,936 08_多级index.ipynb
# 2019/07/17  13:44            15,033 09_Mapping&Replace.ipynb
# 2019/07/16  17:11            93,615 10_Dataframe数学计算与排序.ipynb
# 2019/07/17  13:54            14,046 11_DataFrame_Index_Rename.ipynb
# 2019/07/17  14:18            10,852 11_Merge.ipynb
# 2019/07/17  14:52            20,182 12_Conctenate&Combine.ipynb
# 2019/07/17  15:57            73,321 13_Apply.ipynb
# 2019/07/17  16:06            12,843 14_数据清洗.ipynb
# 2019/07/17  16:32            74,570 15_时间序列.ipynb
# 2019/07/17  19:41            39,347 16_数据分箱&分组.ipynb
# 2019/07/17  19:53            13,091 17_数据聚合.ipynb
# 2019/07/18  19:06                72 18_test.ipynb
# 2019/07/17  19:13               417 city_weather.csv
# 2018/03/24  21:12         1,518,814 food_info.csv
# 2019/07/17  15:56           713,175 food_new.csv
# 2018/03/24  21:12            61,194 titanic_train.csv
# 2019/07/18  13:31        10,578,201 usa_flights.csv
#               24 个文件     13,422,097 字节
#                3 个目录 54,549,340,160 可用字节

# %%
df = pd.read_csv('usa_flights.csv')

# %%
df.head()
# Out:
#        flight_date unique_carrier  flight_num         ...          nas_delay security_delay  actual_elapsed_time
# 0  02/01/2015 0:00             AA           1         ...                NaN            NaN                381.0
# 1  03/01/2015 0:00             AA           1         ...                NaN            NaN                358.0
# 2  04/01/2015 0:00             AA           1         ...                NaN            NaN                385.0
# 3  05/01/2015 0:00             AA           1         ...                NaN            NaN                389.0
# 4  06/01/2015 0:00             AA           1         ...               25.0            0.0                424.0
#
# [5 rows x 14 columns]

# %%
df.tail()
# Out:
#             flight_date unique_carrier  flight_num         ...          nas_delay security_delay  actual_elapsed_time
# 201659  10/01/2015 0:00             NK         188         ...                NaN            NaN                 77.0
# 201660  11/01/2015 0:00             NK         188         ...                NaN            NaN                 87.0
# 201661  12/01/2015 0:00             NK         188         ...                NaN            NaN                 82.0
# 201662  13/01/2015 0:00             NK         188         ...               20.0            0.0                103.0
# 201663  14/01/2015 0:00             NK         188         ...                NaN            NaN                 82.0
#
# [5 rows x 14 columns]

# %%
#获取延误时间最长top10
df.sort_values('arr_delay',ascending=False)[:10]
# Out:
#            flight_date unique_carrier  flight_num         ...          nas_delay security_delay  actual_elapsed_time
# 11073  11/01/2015 0:00             AA        1595         ...                0.0            0.0                 59.0
# 10214  13/01/2015 0:00             AA        1487         ...                0.0            0.0                117.0
# 12430  03/01/2015 0:00             AA        1677         ...                4.0            0.0                104.0
# 8443   04/01/2015 0:00             AA        1279         ...                0.0            0.0                102.0
# 10328  05/01/2015 0:00             AA        1495         ...                0.0            0.0                127.0
# 36570  04/01/2015 0:00             DL        1435         ...                0.0            0.0                231.0
# 36495  04/01/2015 0:00             DL        1367         ...               26.0            0.0                171.0
# 59072  14/01/2015 0:00             DL        1687         ...               14.0            0.0                240.0
# 32173  05/01/2015 0:00             AA         970         ...                0.0            0.0                 66.0
# 56488  12/01/2015 0:00             DL        2117         ...                0.0            0.0                193.0
#
# [10 rows x 14 columns]

# %%
#2.延误与未延误比例

# %%
df['cancelled'].value_counts()
# Out:
# 0    196873
# 1      4791
# Name: cancelled, dtype: int64

# %%
df['delayed'] = df['arr_delay'].apply(lambda x :x>0)

# %%
df
# Out:
#             flight_date unique_carrier  flight_num   ...    security_delay actual_elapsed_time  delayed
# 0       02/01/2015 0:00             AA           1   ...               NaN               381.0    False
# 1       03/01/2015 0:00             AA           1   ...               NaN               358.0    False
# 2       04/01/2015 0:00             AA           1   ...               NaN               385.0    False
# 3       05/01/2015 0:00             AA           1   ...               NaN               389.0    False
# 4       06/01/2015 0:00             AA           1   ...               0.0               424.0     True
# 5       07/01/2015 0:00             AA           1   ...               NaN               382.0    False
# 6       08/01/2015 0:00             AA           1   ...               NaN               362.0    False
# 7       09/01/2015 0:00             AA           1   ...               NaN               400.0     True
# 8       10/01/2015 0:00             AA           1   ...               NaN               392.0    False
# 9       11/01/2015 0:00             AA           1   ...               NaN               365.0    False
# 10      12/01/2015 0:00             AA           1   ...               NaN               397.0    False
# 11      13/01/2015 0:00             AA           1   ...               NaN               361.0    False
# 12      14/01/2015 0:00             AA           1   ...               NaN               330.0    False
# 13      02/01/2015 0:00             AA           2   ...               NaN               333.0    False
# 14      03/01/2015 0:00             AA           2   ...               0.0               337.0     True
# 15      04/01/2015 0:00             AA           2   ...               0.0               324.0     True
# 16      05/01/2015 0:00             AA           2   ...               NaN               328.0    False
# 17      06/01/2015 0:00             AA           2   ...               NaN               313.0    False
# 18      07/01/2015 0:00             AA           2   ...               NaN               320.0    False
# 19      08/01/2015 0:00             AA           2   ...               NaN               316.0    False
# 20      09/01/2015 0:00             AA           2   ...               NaN               319.0    False
# 21      10/01/2015 0:00             AA           2   ...               NaN               324.0    False
# 22      11/01/2015 0:00             AA           2   ...               NaN               330.0    False
# 23      12/01/2015 0:00             AA           2   ...               NaN               338.0     True
# 24      13/01/2015 0:00             AA           2   ...               NaN               323.0    False
# 25      14/01/2015 0:00             AA           2   ...               NaN               328.0    False
# 26      02/01/2015 0:00             AA           3   ...               NaN               361.0    False
# 27      03/01/2015 0:00             AA           3   ...               NaN               369.0    False
# 28      04/01/2015 0:00             AA           3   ...               NaN               380.0    False
# 29      05/01/2015 0:00             AA           3   ...               NaN               390.0     True
# ...                 ...            ...         ...   ...               ...                 ...      ...
# 201634  11/01/2015 0:00             NK         188   ...               0.0               269.0     True
# 201635  12/01/2015 0:00             NK         188   ...               NaN               235.0    False
# 201636  13/01/2015 0:00             NK         188   ...               0.0               244.0     True
# 201637  14/01/2015 0:00             NK         188   ...               NaN               237.0    False
# 201638  02/01/2015 0:00             NK         188   ...               NaN               116.0    False
# 201639  03/01/2015 0:00             NK         188   ...               NaN               121.0    False
# 201640  04/01/2015 0:00             NK         188   ...               0.0               136.0     True
# 201641  05/01/2015 0:00             NK         188   ...               0.0               129.0     True
# 201642  06/01/2015 0:00             NK         188   ...               NaN                 NaN    False
# 201643  07/01/2015 0:00             NK         188   ...               NaN                 NaN    False
# 201644  08/01/2015 0:00             NK         188   ...               NaN               110.0    False
# 201645  09/01/2015 0:00             NK         188   ...               0.0               116.0     True
# 201646  10/01/2015 0:00             NK         188   ...               0.0               103.0     True
# 201647  11/01/2015 0:00             NK         188   ...               NaN               116.0     True
# 201648  12/01/2015 0:00             NK         188   ...               NaN                 NaN    False
# 201649  13/01/2015 0:00             NK         188   ...               NaN               134.0    False
# 201650  14/01/2015 0:00             NK         188   ...               NaN               127.0    False
# 201651  02/01/2015 0:00             NK         188   ...               NaN                86.0     True
# 201652  03/01/2015 0:00             NK         188   ...               NaN                79.0    False
# 201653  04/01/2015 0:00             NK         188   ...               NaN                86.0    False
# 201654  05/01/2015 0:00             NK         188   ...               NaN                84.0    False
# 201655  06/01/2015 0:00             NK         188   ...               NaN                90.0     True
# 201656  07/01/2015 0:00             NK         188   ...               NaN                92.0     True
# 201657  08/01/2015 0:00             NK         188   ...               NaN                83.0    False
# 201658  09/01/2015 0:00             NK         188   ...               NaN                88.0    False
# 201659  10/01/2015 0:00             NK         188   ...               NaN                77.0    False
# 201660  11/01/2015 0:00             NK         188   ...               NaN                87.0    False
# 201661  12/01/2015 0:00             NK         188   ...               NaN                82.0    False
# 201662  13/01/2015 0:00             NK         188   ...               0.0               103.0     True
# 201663  14/01/2015 0:00             NK         188   ...               NaN                82.0    False
#
# [201664 rows x 15 columns]

# %%
delay_data = df['delayed'].value_counts()
delay_data
# Out:
# False    103037
# True      98627
# Name: delayed, dtype: int64

# %%
type(delay_data)
# Out:
# pandas.core.series.Series

# %%
#延误比
delay_data[1]/(delay_data[0]+delay_data[1])
# Out:
# 0.4890659711202793

# %%
# 3.每个公司延误情况

# %%
delay_group0 = df.groupby(['unique_carrier'])
delay_group0.size()
# Out:
# unique_carrier
# AA    18753
# AS     5631
# B6     9233
# DL    27522
# EV    21967
# F9     2951
# HA     2705
# MQ    12752
# NK     3683
# OO    20781
# UA    16509
# US    14203
# VX     2035
# WN    42939
# dtype: int64

# %%
delay_group = df.groupby(['unique_carrier','delayed'])
df_delay = delay_group.size().unstack()
df_delay
# Out:
# delayed         False  True
# unique_carrier
# AA               8912   9841
# AS               3527   2104
# B6               4832   4401
# DL              17719   9803
# EV              10596  11371
# F9               1103   1848
# HA               1351   1354
# MQ               4692   8060
# NK               1550   2133
# OO               9977  10804
# UA               7885   8624
# US               7850   6353
# VX               1254    781
# WN              21789  21150

# %%
import matplotlib.pyplot as plt

# %%
df_delay.plot()

# %%
plt.show()
